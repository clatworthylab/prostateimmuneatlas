# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

warnings.filterwarnings('ignore')
os.chdir(os.path.expanduser('/home/jovyan/Prostate_analysis/scanpy'))
sc.settings.verbosity = 3
sc.logging.print_versions()

results_file = 'dataset/spleen.cellxgene.h5ad'

adata = sc.read_h5ad(results_file)
adata
# Out:
# scanpy==1.4.5.post2 anndata==0.6.22.post1 umap==0.3.10 numpy==1.17.2 scipy==1.4.1 pandas==0.25.1 scikit-learn==0.22.1 statsmodels==0.11.0rc1 python-igraph==0.7.1 louvain==0.6.1
# AnnData object with n_obs × n_vars = 94257 × 22612
#     obs: 'Donor', 'Time', 'donor_time', 'organ', 'patient', 'sample', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Celltypes'
#     var: 'gene_ids-HCATisStab7463846', 'gene_ids-HCATisStab7463847', 'gene_ids-HCATisStab7463848', 'gene_ids-HCATisStab7463849', 'gene_ids-HCATisStab7587200', 'gene_ids-HCATisStab7587203', 'gene_ids-HCATisStab7587206', 'gene_ids-HCATisStab7587209', 'gene_ids-HCATisStabAug177078016', 'gene_ids-HCATisStabAug177078017', 'gene_ids-HCATisStabAug177078018', 'gene_ids-HCATisStabAug177078019', 'gene_ids-HCATisStabAug177276391', 'gene_ids-HCATisStabAug177276392', 'gene_ids-HCATisStabAug177276394', 'gene_ids-HCATisStabAug177376561', 'gene_ids-HCATisStabAug177376563', 'gene_ids-HCATisStabAug177376565', 'gene_ids-HCATisStabAug177376567', 'n_cells'
#     uns: 'Celltypes_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
list(set(adata.obs['Celltypes']))
# Out:
# ['T_CD4_fh',
#  'B_mantle',
#  'T_cell_dividing',
#  'Plasmablast',
#  'NK_CD160pos',
#  'T_CD8_MAIT',
#  'T_CD8_activated',
#  'Monocyte',
#  'Platelet',
#  'T_CD8_gd',
#  'DC_plasmacytoid',
#  'T_CD4_conv',
#  'DC_activated',
#  'ILC',
#  'B_follicular',
#  'B_T_doublet',
#  'Plasma_IgM',
#  'NK_dividing',
#  'T_CD4_naive',
#  'Plasma_IgG',
#  'Unknown',
#  'CD34_progenitor',
#  'Macrophage',
#  'B_Hypermutation',
#  'T_CD4_reg',
#  'T_CD8_CTL',
#  'NK_FCGR3Apos',
#  'DC_2',
#  'DC_1']

# %%
# subset to macrophages and monocyte
adata = adata[adata.obs['Celltypes'].isin(['DC_activated','DC_1','DC_2','Monocyte', 'Macrophage'])]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 6613 × 22612
#     obs: 'Donor', 'Time', 'donor_time', 'organ', 'patient', 'sample', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Celltypes'
#     var: 'gene_ids-HCATisStab7463846', 'gene_ids-HCATisStab7463847', 'gene_ids-HCATisStab7463848', 'gene_ids-HCATisStab7463849', 'gene_ids-HCATisStab7587200', 'gene_ids-HCATisStab7587203', 'gene_ids-HCATisStab7587206', 'gene_ids-HCATisStab7587209', 'gene_ids-HCATisStabAug177078016', 'gene_ids-HCATisStabAug177078017', 'gene_ids-HCATisStabAug177078018', 'gene_ids-HCATisStabAug177078019', 'gene_ids-HCATisStabAug177276391', 'gene_ids-HCATisStabAug177276392', 'gene_ids-HCATisStabAug177276394', 'gene_ids-HCATisStabAug177376561', 'gene_ids-HCATisStabAug177376563', 'gene_ids-HCATisStabAug177376565', 'gene_ids-HCATisStabAug177376567', 'n_cells'
#     uns: 'Celltypes_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
# save first
adata.write('dataset/spleen.h5ad', compression = 'gzip')

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

warnings.filterwarnings('ignore')
os.chdir(os.path.expanduser('/home/jovyan/Prostate_analysis/scanpy'))
sc.settings.verbosity = 3
sc.logging.print_versions()

results_file = 'dataset/spleen.h5ad'

adata = sc.read_h5ad(results_file)
adata
# Out:
# /home/jovyan/my-conda-envs/mypython3/lib/python3.7/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# scanpy==1.4.5.post2 anndata==0.6.22.post1 umap==0.3.10 numpy==1.17.2 scipy==1.4.1 pandas==0.25.1 scikit-learn==0.22.1 statsmodels==0.11.0rc1 python-igraph==0.7.1 louvain==0.6.1
# AnnData object with n_obs × n_vars = 6613 × 22612
#     obs: 'Donor', 'Time', 'donor_time', 'organ', 'patient', 'sample', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Celltypes', 'Mac1_score', 'Mac2_score', 'Mac-MT1_score', 'Mono_score', 'DC_score', 'Mac-cycling_score'
#     var: 'gene_ids-HCATisStab7463846', 'gene_ids-HCATisStab7463847', 'gene_ids-HCATisStab7463848', 'gene_ids-HCATisStab7463849', 'gene_ids-HCATisStab7587200', 'gene_ids-HCATisStab7587203', 'gene_ids-HCATisStab7587206', 'gene_ids-HCATisStab7587209', 'gene_ids-HCATisStabAug177078016', 'gene_ids-HCATisStabAug177078017', 'gene_ids-HCATisStabAug177078018', 'gene_ids-HCATisStabAug177078019', 'gene_ids-HCATisStabAug177276391', 'gene_ids-HCATisStabAug177276392', 'gene_ids-HCATisStabAug177276394', 'gene_ids-HCATisStabAug177376561', 'gene_ids-HCATisStabAug177376563', 'gene_ids-HCATisStabAug177376565', 'gene_ids-HCATisStabAug177376567', 'n_cells'
#     uns: 'Celltypes_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
def bh(pvalues):
    '''
    Computes the Benjamini-Hochberg FDR correction.
    
    Input:
        * pvals - vector of p-values to correct
    '''
    n = int(pvalues.shape[0])
    new_pvalues = np.empty(n)
    values = [ (pvalue, i) for i, pvalue in enumerate(pvalues) ]
    values.sort()
    values.reverse()
    new_values = []
    for i, vals in enumerate(values):
        rank = n - i
        pvalue, index = vals
        new_values.append((n/rank) * pvalue)
    for i in range(0, int(n)-1):
        if new_values[i] < new_values[i+1]:
            new_values[i+1] = new_values[i]
    for i, vals in enumerate(values):
        pvalue, index = vals
        new_pvalues[index] = new_values[i]
    return new_pvalues

# %%
# now compute Mac-MT1 score p-values. figure out the global median and mad (from above-median values) for the distribution for each celltype
med = np.median(adata.obs['Mac-MT1_score'])
mask = adata.obs['Mac-MT1_score']>med
mad = np.median(adata.obs['Mac-MT1_score'][mask]-med)
# do a one-sided test with Krystoff's implementation
pvals = 1-scipy.stats.norm.cdf(adata.obs['Mac-MT1_score'], loc=med, scale=1.4826*mad)
adata.obs['bh_pval'] = bh(pvals)

# %%
# threshold the p-values to get potential Mac-MT1 calls.
adata.obs['similar_to_Mac-MT1'] = (adata.obs['bh_pval'] < 0.05) & (adata.obs['Mac-MT1_score'] > 0.5)
adata.obs['similar_to_Mac-MT1'] = adata.obs['similar_to_Mac-MT1'].astype('category')
# visualise the Mac-MT1
adata.uns['similar_to_Mac-MT1_colors'] = ['#e5e5e5', '#e15759']
sc.set_figure_params(figsize = [6.0, 4.0], vector_friendly = True, dpi_save = 900)
sc.pl.umap(adata, color = ['Mac-MT1_score', 'similar_to_Mac-MT1', 'similar_to_Mac-MT1'], size = 200, groups = [True], save = '/Spleen_similarity_to_Mac-MT1.pdf', color_map = 'cool_r', vmax = 1, ncols = 3)
# Out:
# WARNING: saving figure to file figures/umap/Spleen_similarity_to_Mac-MT1.pdf

# %%
sc.pl.umap(adata, color = ['Celltypes','Celltypes','Celltypes'], size = 200, save = '/Spleen_MNP_celltypes.pdf', ncols = 3)
# Out:
# WARNING: saving figure to file figures/umap/Spleen_MNP_celltypes.pdf

# %%
sc.pl.umap(adata, color = ['DC_score', 'Mac1_score', 'Mac2_score', 'Mono_score', 'Mac-cycling_score', 'Mac-MT1_score'], size =50, color_map = 'cool_r', vmax = 1)

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

warnings.filterwarnings('ignore')
os.chdir(os.path.expanduser('/home/jovyan/Prostate_analysis/scanpy'))
sc.settings.verbosity = 3
sc.logging.print_versions()

results_file = 'dataset/spleen.h5ad'

adata = sc.read_h5ad(results_file)
adata
# Out:
# /home/jovyan/my-conda-envs/mypython3/lib/python3.7/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# scanpy==1.4.5.post2 anndata==0.6.22.post1 umap==0.3.10 numpy==1.17.2 scipy==1.4.1 pandas==0.25.1 scikit-learn==0.22.1 statsmodels==0.11.0rc1 python-igraph==0.7.1 louvain==0.6.1
# AnnData object with n_obs × n_vars = 6613 × 22612
#     obs: 'Donor', 'Time', 'donor_time', 'organ', 'patient', 'sample', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Celltypes', 'Mac1_score', 'Mac2_score', 'Mac-MT1_score', 'Mono_score', 'DC_score', 'Mac-cycling_score'
#     var: 'gene_ids-HCATisStab7463846', 'gene_ids-HCATisStab7463847', 'gene_ids-HCATisStab7463848', 'gene_ids-HCATisStab7463849', 'gene_ids-HCATisStab7587200', 'gene_ids-HCATisStab7587203', 'gene_ids-HCATisStab7587206', 'gene_ids-HCATisStab7587209', 'gene_ids-HCATisStabAug177078016', 'gene_ids-HCATisStabAug177078017', 'gene_ids-HCATisStabAug177078018', 'gene_ids-HCATisStabAug177078019', 'gene_ids-HCATisStabAug177276391', 'gene_ids-HCATisStabAug177276392', 'gene_ids-HCATisStabAug177276394', 'gene_ids-HCATisStabAug177376561', 'gene_ids-HCATisStabAug177376563', 'gene_ids-HCATisStabAug177376565', 'gene_ids-HCATisStabAug177376567', 'n_cells'
#     uns: 'Celltypes_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
sc.pl.dotplot(adata, ['IL2RA', 'IL2RB', 'IL2RG'], groupby = 'Celltypes', color_map = 'PuRd', use_raw = True)
# Out:
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[1.0499999999999998, 0, 0.2, 0.5, 0.25])
