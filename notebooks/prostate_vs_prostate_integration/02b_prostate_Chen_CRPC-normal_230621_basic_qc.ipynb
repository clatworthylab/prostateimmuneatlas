# %%
# file corrupted at step 9. have to redo this dataset.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import tools

warnings.filterwarnings('ignore')
os.chdir(os.path.expanduser('/lustre/scratch117/cellgen/team297/kt16/Prostate_analysis/scanpy'))
sc.settings.verbosity = 3
sc.logging.print_header()
# Out:
# scanpy==1.7.2 anndata==0.7.6 umap==0.5.1 numpy==1.20.2 scipy==1.6.2 pandas==1.2.4 scikit-learn==0.24.2 statsmodels==0.12.2 python-igraph==0.9.1

# %%
adata = sc.read_h5ad('dataset/Chen/chen_11.h5ad')

adata.layers["counts"] = adata.X.copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 46117 × 39899
#     obs: 'barcode', 'study', 'sample', 'group'
#     var: 'GeneID'
#     layers: 'counts'

# %%
import dandelion as ddl
ddl.pp.recipe_scanpy_qc(adata, mito_cutoff = 30)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:22)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:17)
# running Leiden clustering
#     finished: found 38 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)
# running Leiden clustering
#     finished: found 51 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 60 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 70 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 83 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 95 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 108 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 117 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 131 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 139 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 155 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 164 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 176 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 189 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 201 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 210 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 220 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 228 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 242 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 252 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 259 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 269 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 277 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 285 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 295 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 305 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 313 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 320 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 329 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 336 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 341 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 346 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 348 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 363 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 372 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 381 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 391 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 405 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 413 clusters and added
#     'leiden_R', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
adata = adata[adata.obs['filter_rna'] == False]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 41516 × 39899
#     obs: 'barcode', 'study', 'sample', 'group', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'is_doublet', 'filter_rna'
#     var: 'GeneID'
#     layers: 'counts'

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata
adata = adata[:, adata.var.highly_variable]

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca_variance_ratio(adata, log=True, n_pcs = 50)
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:49)
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:05)

# %%
import bbknn

# %%
# sc.external.pp.bbknn not updated yet
bbknn.bbknn(adata, batch_key='sample')
sc.tl.umap(adata, min_dist = 0.3)
sc.pl.umap(adata, color = 'sample')
# Out:
# computing batch balanced neighbors
# 	finished: added to `.uns['neighbors']`
# 	`.obsp['distances']`, distances for each pair of neighbors
# 	`.obsp['connectivities']`, weighted adjacency matrix (0:00:10)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:49)

# %%
sc.pl.umap(adata, color = ['CD68', 'MT1H', 'KLK3', 'KLK4'], ncols =2)

# %%
sc.tl.leiden(adata)
sc.pl.umap(adata, color = 'leiden')
# Out:
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:18)

# %%
adata.write_h5ad('dataset/Chen/chen_11_filtered.h5ad', compression = 'gzip')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 41516 × 4624
#     obs: 'barcode', 'study', 'sample', 'group', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'is_doublet', 'filter_rna', 'leiden'
#     var: 'GeneID', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca', 'neighbors', 'umap', 'sample_colors', 'leiden', 'leiden_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'
