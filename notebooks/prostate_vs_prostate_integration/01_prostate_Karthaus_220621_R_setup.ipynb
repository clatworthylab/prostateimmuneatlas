# %%
library(DropletUtils)
setwd('/lustre/scratch117/cellgen/team297/kt16/Prostate_analysis/scanpy/dataset')
# Out:
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
# ...

# %%
sce <- read10xCounts('Karthaus', compressed = TRUE)
sce
# Out:
# class: SingleCellExperiment
# dim: 33538 120300
# metadata(1): Samples
# assays(1): counts
# rownames(33538): ENSG00000243485 ENSG00000237613 ... ENSG00000277475
#   ENSG00000268674
# rowData names(3): ID Symbol Type
# colnames: NULL
# colData names(2): Sample Barcode
# reducedDimNames(0):
# altExpNames(0):

# %%
# read in the metadata
meta = read.csv('Karthaus/hsPortalData_metadata.txt', check.names = FALSE)
meta <- meta[-1,]
row.names(meta) <- meta$NAME
meta <- meta[,-1]
meta
# Out:
#                                                 batchID
# HP100_NT_EPCAMneg_INTACT_19_id-AAACGAACAACCCTCT Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGGGCGTTCCCACT Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGGGCTCAAACGAA Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGGTATCGGAAACG Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGGTATCTAGTTCT Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGTGAAGAAGCTGC Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AAAGTGATCCGCGGAT Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AACAAGACAGACCTAT Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AACAAGAGTTTCGCTC Sample3_HP100_NT_EPCAMneg_INTACT_19
# HP100_NT_EPCAMneg_INTACT_19_id-AACAAGATCGCGCTGA Sample3_HP100_NT_EPCAMneg_INTACT_19
# ...

# %%
# transfer the meta
colData(sce) <- cbind(colData(sce), meta)

# %%
rownames(sce) <- rowData(sce)$Symbol

# %%
sce
# Out:
# class: SingleCellExperiment
# dim: 33538 120300
# metadata(1): Samples
# assays(1): counts
# rownames(33538): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(3): ID Symbol Type
# colnames: NULL
# colData names(10): Sample Barcode ... batch PatientNum
# reducedDimNames(0):
# altExpNames(0):

# %%
sceasy::convertFormat(sce, from="sce", to="anndata", outFile='Karthaus/karthaus.h5ad')
# Out:
# Warning message in .regularise_df(as.data.frame(SummarizedExperiment::colData(obj)), :
# “Dropping single category variables:Sample”
# Warning message in .regularise_df(as.data.frame(SummarizedExperiment::rowData(obj)), :
# “Dropping single category variables:Type”
